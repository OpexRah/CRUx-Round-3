# %%
pip install google-api-python-client

# %%
#keywords
educational_kw = ["maths", "mathematics", "physics", "chemistry", "english", "learning", "veritasium", "how to code", "python", "programming languages", "courses to learn", "machine learning", "artificial intelligence", "colleges", "JEE mains", "JEE advanced", "physics wallah", "physics galaxy", "quantum physics", "learn skills", "how to play sports such as", "rules for sports such as", "how to make", "how to do", "how to learn", "biology videos", "human anatomy", "plant biology", "science", "computer and technology"]
music_kw = ["2023 billboard songs", "most popular songs", "the weeknd", "ariana grande", "taylor swift", "logic music", "eminem music", "metro boomin", "vevo", "rap songs", "juice wrld", "rock music", "electrical guitar", "jazz music", "piano covers", "drum covers", "beatbox", "the kid laroi", "doja cat", "classical songs", "music video", "official visualizer", "official video", "bollywood hitlist", "hindi party songs new", "arijit singh", "pritam songs", "mashup songs", "instrument covers for popular songs", "best movie soundtracks"]
sport_kw = ["sports news", "chess", "badminton", "table tennis", "lawn tennis", "cricket", "football", "basketball", "hockey", "volleyball", "boxing", "UFC", "MS Dhoni", "Virat Kohli", "Ronaldo", "Messi", "weightlifting", "body building", "calisthenics", "workout routines", "Olympics", "Paralympics", "Michael Jordan", "How to play sports", "best sport moments", "fitness routines", "muscle", "athletics", "F1 racing", "Rules of F1"]
games_kw = ["spider man 2 game", "new games to play", "gta 5", "gta san andreas", "gaming laptop", "gaming pc", "fortnite", "minecraft", "mrbeastgaming", "ps5 games", "xbox one", "league of legends", "esports games", "clash royale", "hill climb racing", "android games", "ios games", "red dead redemption", "the witcher 3", "harry potter legacy", "forza horizon", "battle royale pubg", "gaming phone", "video games", "real racing 3", "world of tanks", "flight simulator x", "rocket league", "cloud gaming", "genshin impact"]
movie_kw = ["netflix", "amazon prime", "movies to watch", "friends show", "hulu", "anime", "crunchyroll", "attack on titan", "top gun maverick", "mission impossible", "spiderverse", "marvel movies", "iron man", "endgame", "demon slayer", "two and a half men", "big bang theory", "barbie movie", "oppenheimer movie", "cinema", "films", "imax camera", "titanic movie", "blockbuster", "transformers movie", "the conjuring movie", "sitcoms", "jujutsu kaisen", "star wars", "batman movie"]

# %%
# API client library
import googleapiclient.discovery
import re
# API information
api_service_name = "youtube"
api_version = "v3"
# API key

DEVELOPER_KEY = "AIzaSyD_ifEnkFx2kFjIJHBt-2z5FNvAaNL9oj0"
# API client
youtube = googleapiclient.discovery.build(api_service_name, api_version, developerKey = DEVELOPER_KEY)
# 'request' variable is the only thing you must change
# depending on the resource and method you need to use
keyword_list = movie_kw
titles = []
ids = []
# in your query
for keyword in keyword_list:
  request = youtube.search().list(
          part="id,snippet",
          type='video',
          fields="items(id(videoId),snippet(title,description))",
          q=keyword,
          maxResults=60
  )
  # Query execution
  response = request.execute()
  # Print the results
  #print(response)

  for i in range(0,50):
    final_title = ""
    title = response["items"][i]["snippet"]["title"]
    title_word_list = title.split(" ")
    for word in title_word_list:
      #word_filtered = ''.join(filter(str.isalnum, word))
      pattern = r'[^A-Za-z0-9]+'
      word_filtered = re.sub(pattern, '', word)
      final_title += word_filtered + " "
    id = response["items"][i]["id"]["videoId"]
    titles.append(final_title.lower())
    ids.append(id)
    print(final_title)
# Out:
# Squid Game The Challenge  Official Trailer  Netflix
# New on Netflix  November 2023
# MINIMALISM Official Netflix Documentary Entire Film
# Maestro  Official Trailer  Netflix
# Why Netflix is Collapsing The Truth About Netflix39s Empire
# Leave The World Behind  Official Trailer  Netflix
# Top 10 Best NETFLIX Movies to Watch Now 2023
# Our Planet  From Deserts to Grasslands  FULL EPISODE  Netflix
# Doona  Official Trailer  Netflix
# New on Netflix  October 2023
# Castaway Diva  Official Clip  Netflix ENG SUB
# Best Christmas Ever  Official Trailer  Netflix
# Why Netflix Won39t Die
# Geeked Week 2023  Official Trailer  Netflix
# Mighty Little Bheem FULL EPISODES 14  Season 1 Compilation  Netflix Jr
# ONE PIECE  Official Teaser Trailer  Netflix
# Netflix39s Q4 subscriber growth outlook is a 39big surprise39 says Evercore ISI39s Mark Mahaney
# TUDUM 2023 A Netflix Global Fan Event  Live From Brazil
# 3 DISTURBING Netflix Movies you NEED to watch shorts
# ...

# %%
import csv
data_file = open('./jsonoutput.csv', 'w', newline='')
items = response["items"]
csv_writer = csv.writer(data_file)
csv_writer.writerow(["id", "title"])

for i in range(0, len(titles)):
  new = [ids[i], titles[i]]
  csv_writer.writerow(new)

data_file.close()
